# %% [markdown]
# """
# YOLOv8 training was executed using the Ultralytics CLI (command line).
# This notebook documents:
# - the dataset configuration (data/waid.yaml)
# - the exact CLI command to run training
# - the outputs produced in runs/detect/train (args.yaml, results.csv, weights, plots)
#
# This ensures the repository remains reproducible and understandable even if the original notebook was lost.
# """

# %%
# !yolo --version

# %%
# !type data\waid.yaml
# !type data\classes.txt

# %% [markdown]
# ## Commande de training (à relancer si besoin)

# %%
# !yolo detect train data=data/waid.yaml model=yolov8s.pt imgsz=640 epochs=50 batch=16

# %% [markdown]
# ## Afficher les outputs déjà générés

# %%
# !dir runs\detect\train
# !dir runs\detect\train\weights

# %%
## Lire la config exacte du run

# %%
# !type runs\detect\train\args.yaml

# %% [markdown]
# ##

# %%
# !type runs\detect\train\results.csv
